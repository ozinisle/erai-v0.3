# %%
dataName = 'crudeOilFeb'
dataFrequency='5m'

import os
import sys  
import matplotlib

module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)

# %matplotlib notebook

print("module_path >>> " + module_path + " <<< appended to sys path - Mandatory for the pythons files in src folder to be recognized")
# Out:
# module_path >>> /Users/493055/Desktop/dev/erai-v0.3/src <<< appended to sys path - Mandatory for the pythons files in src folder to be recognized

# %%
from dataPreparation import *

from dataPreparation.platform import createPlatform, createFundamentalFeatures

baseDf = createPlatform(dataName,dataFrequency,getNativeDataOnly=True)

#baseInputDf = createFundamentalFeatures(baseDf)  # data with open close high low
# Out:
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v0.3/src/config/config.json
# before return statement of method doBasicOperation

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure(data=[go.Candlestick(x=baseDf['date-time'],
                open=baseDf['open'],
                high=baseDf['high'],
                low=baseDf['low'],
                close=baseDf['close'])])
fig.update_layout(
    title= {
        'text': 'quote',
      'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
      font=dict(
        family="Courier New, monospace",
        size=20,
        color="#7f7f7f"
    )
    )
fig.show()
# Out:
# <div>
#
#
#             <div id="072f9fe7-2706-4eb3-a071-07c34126666d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("072f9fe7-2706-4eb3-a071-07c34126666d")) {
#                     Plotly.newPlot(
#                         '072f9fe7-2706-4eb3-a071-07c34126666d',
# ...

# %%
from mpl_finance import candlestick2_ohlc
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import datetime as datetime
import numpy as np

quotes = np.array(...)

fig, ax = plt.subplots()
candlestick2_ohlc(ax,baseDf['open'],baseDf['high'],baseDf['low'],baseDf['close'],width=0.6)

xdate = baseDf['date-time'].values #[datetime.datetime.fromtimestamp(i) for i in quotes['time']]

ax.xaxis.set_major_locator(ticker.MaxNLocator(6))

def mydate(x,pos):
    try:
        return xdate[int(x)]
    except IndexError:
        return ''

ax.xaxis.set_major_formatter(ticker.FuncFormatter(mydate))

fig.autofmt_xdate()
fig.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# baseInputDf= baseDf
# baseInputDf.index=baseInputDf['date-time']
# baseInputDf=baseInputDf.drop(['date-time'],axis=1)
# baseInputDf.head()

# %%
#dataDf = baseInputDf

# %%
# import numpy as np
# import pandas as pd

# suppResisDf = dataDf[['close']]

# #suppResisDf['maximaIdxs']  = dataDf['close']

# suppResisDf['maximaIdxs']  = 0

# suppResisDf['maximaIdxs']  = dataDf['close'][(dataDf['close'] > dataDf['close'].shift(1))
#                                              & (dataDf['close'] > dataDf['close'].shift(-1))]
# suppResisDf['minimaIdxs']  = dataDf['close'][(dataDf['close'] < dataDf['close'].shift(1))
#                                              & (dataDf['close'] < dataDf['close'].shift(-1))]

# suppResisDf=suppResisDf.fillna(0)

# suppResisDf['maximaIdxs'][suppResisDf['maximaIdxs']>0] = 1
# suppResisDf['minimaIdxs'][suppResisDf['minimaIdxs']>0] = 1

# suppResisDf.head()
# # from dataPreparation.platform import getFeatureData

# # smaDf = getFeatureData(dataName,dataFrequency,'003_simple_moving_average.csv')

# # smaDf.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# from findiff import FinDiff #pip install findiff
# dx = 1 #1 day interval
# d_dx = FinDiff(0, dx, 1)
# d2_dx2 = FinDiff(0, dx, 2)
# clarr = np.asarray(dataDf['close'].values, dtype=np.float64)
# # clarr = np.multiply(clarr, 1, out=clarr, casting='unsafe')
# mom = d_dx(clarr)
# momacc = d2_dx2(clarr)

# %%
# def get_extrema(isMin):
#   return [x for x in range(len(mom))
#     if (momacc[x] > 0 if isMin else momacc[x] < 0) and
#       (mom[x] == 0 or #slope is 0
#         (x != len(mom) - 1 and #check next day
#           (mom[x] > 0 and mom[x+1] < 0 and
#            h[x] >= h[x+1] or
#            mom[x] < 0 and mom[x+1] > 0 and
#            h[x] <= h[x+1]) or
#          x != 0 and #check prior day
#           (mom[x-1] > 0 and mom[x] < 0 and
#            h[x-1] < h[x] or
#            mom[x-1] < 0 and mom[x] > 0 and
#            h[x-1] > h[x])))]
# minimaIdxs, maximaIdxs = get_extrema(True), get_extrema(False)

# %%
# saveFeatureToDisk(dataName,dataFrequency,gmmaDf,'006_guppy_multiple_moving_average')

# %%
# import datetime as dt
# import matplotlib.dates as mdates
# import matplotlib.pyplot as plt
# import pandas_datareader as web
# from mpl_finance import candlestick_ohlc

# start = dt.datetime(2020,1,1)
# end = dt.datetime.now()

# mod_baseInputDf = baseInputDf
# mod_baseInputDf['Close']=mod_baseInputDf['close'].rename('Close')
# mod_baseInputDf['High']=mod_baseInputDf['high'].rename('High')
# mod_baseInputDf['Open']=mod_baseInputDf['open'].rename('Open')
# mod_baseInputDf['Low']=mod_baseInputDf['low'].rename('Low')

# mod_baseInputDf=mod_baseInputDf.drop(['close','open','high','low'],axis=1)

# mod_baseInputDf['Date'] = dt.fromtimestamp(baseInputDf['date'])

# mod_baseInputDf.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-d179588f7899> in <module>
#      16 mod_baseInputDf=mod_baseInputDf.drop(['close','open','high','low'],axis=1)
#      17
# ---> 18 mod_baseInputDf['Date'] = dt.fromtimestamp(baseInputDf['date'])
#      19
#      20 mod_baseInputDf.head()
#
# AttributeError: module 'datetime' has no attribute 'fromtimestamp'

# %%
# from datetime import datetime


# ax = plt.subplot()
# candlestick_ohlc(ax, mod_baseInputDf.values, width=5, colorup='g', colordown='r')
# ax.xaxis_date()
# ax.grid(True)
# plt.show()

# print('done')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-7389c57caeec> in <module>
#       3 ax.xaxis_date()
#       4 ax.grid(True)
# ----> 5 plt.show()
#       6
#       7 print('done')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
# ...
