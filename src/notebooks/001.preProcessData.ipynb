# %%
dataName = 'crudeOilFeb'
dataFrequency='5m'

import os
import sys  
module_path = os.path.abspath('../'+os.path.join('.'))

sys.path.append(module_path)

print("module_path >>> " + module_path + " <<< appended to sys path - Mandatory for the pythons files in src folder to be recognized")
# Out:
# module_path >>> C:\Users\kalagi01\Desktop\dev\erai-v3.0-master\src <<< appended to sys path - Mandatory for the pythons files in src folder to be recognized

# %%
from dataPreprocessing import *

from dataPreprocessing.preProcessData import preProcessData

preProcessData(dataName,dataFrequency)

print('done')
# Out:
#  data pre-processing >> imported dependencies
# looping through all the files to create input data
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\01.json ...
# File read - SUCCESS
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\02.json ...
# File read - SUCCESS
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\03.json ...
# File read - SUCCESS
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\04.json ...
# File read - SUCCESS
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\05.json ...
# File read - SUCCESS
# reading input file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/raw/5m\06.json ...
# File read - SUCCESS
# added prior_holidays feature in pre-processed data
# added following_holidays feature in pre-processed data
# Attempting to create folder if it does not exist >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m
#  checking if folder existis >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m
# Attempting to create folder if it does not exist >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m/preProcessedData
#  checking if folder existis >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m/preProcessedData
# Attempting to create/update file >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m/preProcessedData/processedRawData.csv
# created raw easy to use csv data to be used for preparing training data in the location  >>>C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/data/crudeOilFeb/processed/5m/preProcessedData/processedRawData.csv
#  creating/updating config file
#  retrieving values configured in >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/src/config/config.json
#  updating config file >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/src/config/config.json
#  successfully updated config file >>> (try block) C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/src/config/config.json with data >>>{"crudeOilFeb": {"5m": {"preProcessedDataFilePath": "/data/crudeOilFeb/processed/5m/preProcessedData/processedRawData.csv"}}}
# done

# %%
from dataPreprocessing.preProcessData import getPreprocessedData
preProcessedDf=getPreprocessedData(dataName,dataFrequency)
preProcessedDf.tail()
# Out:
# projectRootFolderPath >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master
#  retrieving values configured in >>> C:/Users/kalagi01/Desktop/dev/erai-v3.0-master/src/config/config.json
#       open  high   low  close  quantity  dont-know  date-timeYear  \
# 6892  3629  3634  3629   3634      2876      39467           2020
# 6893  3634  3637  3632   3636      2185      39763           2020
# 6894  3636  3637  3621   3624      7328      40215           2020
# 6895  3623  3626  3620   3623      4101      40575           2020
# 6896  3622  3625  3620   3621      1050      40506           2020
#
#       date-timeMonth  date-timeWeek  date-timeDay  date-timeDayofweek  \
# 6892               2              6             6                   3
# 6893               2              6             6                   3
# 6894               2              6             6                   3
# 6895               2              6             6                   3
# 6896               2              6             6                   3
#
#       date-timeDayofyear  date-timeIs_month_end  date-timeIs_month_start  \
# 6892                  37                  False                    False
# 6893                  37                  False                    False
# 6894                  37                  False                    False
# 6895                  37                  False                    False
# 6896                  37                  False                    False
#
#       date-timeIs_quarter_end  date-timeIs_quarter_start  \
# 6892                    False                      False
# 6893                    False                      False
# 6894                    False                      False
# 6895                    False                      False
# 6896                    False                      False
#
#       date-timeIs_year_end  date-timeIs_year_start  date-timeElapsed  \
# 6892                 False                   False        1580993400
# 6893                 False                   False        1580993700
# 6894                 False                   False        1580994000
# 6895                 False                   False        1580994300
# 6896                 False                   False        1580994600
#
#       prior_holidays  following_holidays
# 6892               0                   0
# 6893               0                   0
# 6894               0                   0
# 6895               0                   0
# 6896               0                   0
